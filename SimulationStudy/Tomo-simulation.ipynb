# %%
import numpy as np
import gurobipy as grb
import csv
import time
import statsmodels.api as sm
from joblib import Parallel,delayed

def five_variate(n,SNR,rho):
    beta1 = np.array([1,1,1,0,1])
    beta2 = np.array([-1,-1,-1,0,-1])
    p = len(beta1)
    Sigma = np.zeros((p,p));
    for i in range(p):
        for j in range(p):
            Sigma[i,j] = rho**(abs(i-j))
    X = np.random.multivariate_normal(mean =np.zeros(p), cov = Sigma, size = n)
    noise1 = np.random.normal(0,np.sqrt(np.var(X[:int(n/2)]@beta1)/SNR), size = int(n/2)) 
    noise2 = np.random.normal(0,np.sqrt(np.var(X[:int(n/2)]@beta2)/SNR), size = int(n/2)) 
    Y1 = X[:int(n/2)]@beta1 + noise1
    Y2 = X[int(n/2):]@beta2 + noise2
    Y = np.r_[Y1,Y2]
    lam = 0.1*n
    ols = sm.OLS(Y, X)
    ols_result = ols.fit()
    bigM = 10*float(1.96*(sum(ols_result.bse)))#1000

    M = grb.Model()
    M.Params.TimeLimit = 400
    beta = M.addMVar((int(n),5), lb = -grb.GRB.INFINITY)
    z = M.addMVar(len(Y) - 1, vtype = grb.GRB.BINARY)
    sum_of_sq = sum((Y[t] - sum(X[t,j]*beta[t,j] for j in range(5)))* (Y[t] - sum(X[t,j]*beta[t,j] for j in range(5))) for t in range(len(Y)))
    for t in range(len(Y)-1):
        for j in range(5):
            M.addConstr(beta[t+1,j] - beta[t,j] <= bigM*z[t])
            M.addConstr(beta[t+1,j] - beta[t,j] >= -bigM*z[t])
    #optional constratins to add more cuts
    M.addConstr(sum(z) <= 5)
    for t in range(1, len(Y) - 2):
        M.addConstr(z[t-1] + z[t] + z[t+1] <= 1)
    M.setObjective(sum_of_sq+ lam*sum(z))
    M.optimize()
    beta_hat = [beta[t].x for t in range(len(Y))]
    z_hat = [z[t].x for t in range(len(Y)-1)]
    opt_gap = M.MIPGap
    return z_hat, opt_gap,beta_hat

SNR_list = np.array([6, 3.52, 2.07, 1.22, 0.71])
rho_list = np.array([0, 0.3, 0.7])
n_list = np.array([1000])

header = ['Repitition','Time','rho', 'SNR', 'n', 'Optimality Gap', 'Change Points']#, 'beta_hat', 'nonzero count']
f = open('simulation_five_variate.csv', 'w')
writer = csv.writer(f)
writer.writerow(header)
f.close()

def to_repeat(rep):
    for n in n_list:
        for SNR in SNR_list:
            for rho in rho_list:
                tik = time.time()
                z_hat, opt_gap, beta_hat = five_variate(n,SNR,rho)
                tok = time.time()
                duration = tok - tik
                cps = [idx for idx,item in enumerate(z_hat) if item == 1 ]
                # Write result
                resultrow = [rep,duration,rho,SNR, n, opt_gap, cps]
                f = open('simulation_five_variate.csv', 'a')
                writer = csv.writer(f)
                writer.writerow(resultrow)
                f.close()
                
Parallel(n_jobs = 8)(delayed(to_repeat)(rep) for rep in range(500)) #Tomo's machine has 8 cores.
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-07
# Set parameter TimeLimit to value 400
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-07
# Academic license - for non-commercial use only - expires 2024-01-07
# Set parameter TimeLimit to value 400
# Set parameter TimeLimit to value 400
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-07
# Set parameter TimeLimit to value 400
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-07
# Set parameter TimeLimit to value 400
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-07
# Set parameter TimeLimit to value 400
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-07
# Academic license - for non-commercial use only - expires 2024-01-07
# Set parameter TimeLimit to value 400
# Set parameter TimeLimit to value 400
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xacc93ef2
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [2e-04, 1e+02]
#   QObjective range [7e-08, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 4239.1337037
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xe4bc8d7d
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [5e-05, 1e+02]
#   QObjective range [1e-08, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 4767.2672390
# Presolve time: 0.02s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Presolve time: 0.02s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xfe306f14
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [8e-05, 1e+02]
#   QObjective range [1e-06, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 4448.3237377
# Presolve time: 0.03s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xb9a3ca49
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e-04, 1e+02]
#   QObjective range [3e-08, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 4557.2197859
# Presolve time: 0.05s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0x21b117a0
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-04, 1e+02]
#   QObjective range [5e-07, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 4304.9682748
# Presolve time: 0.05s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xb475de68
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e-04, 1e+02]
#   QObjective range [9e-08, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 4540.6790817
# Presolve time: 0.08s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xc3776e78
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [3e-05, 1e+02]
#   QObjective range [7e-11, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Warning: Model contains large quadratic objective coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4902.0875631
# Presolve time: 0.11s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xfa360288
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e-05, 1e+02]
#   QObjective range [8e-08, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 4537.1873248
# Presolve time: 0.11s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    12020    2.1274005e+03   0.000000e+00   3.448060e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11741    2.2232146e+03   0.000000e+00   2.970507e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11892    2.2275284e+03   0.000000e+00   3.473426e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11945    2.3426065e+03   0.000000e+00   3.351295e+03      5s
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11436    2.3540250e+03   0.000000e+00   3.298094e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11949    2.2794338e+03   0.000000e+00   3.416588e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11083    2.3937316e+03   0.000000e+00   3.131338e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11485    2.4214664e+03   0.000000e+00   3.244450e+03      5s
#    15467    1.8760354e+03   0.000000e+00   2.899013e+03     10s
#    23471    1.1944791e+03   0.000000e+00   1.448236e+03     10s
#    16428    1.7971479e+03   0.000000e+00   2.355490e+03     10s
#    16319    1.8378280e+03   0.000000e+00   2.595335e+03     10s
#    15648    1.9096912e+03   0.000000e+00   2.427024e+03     10s
#    16161    1.8366909e+03   0.000000e+00   2.538372e+03     10s
#    15619    1.9000098e+03   0.000000e+00   2.698762e+03     10s
#    16021    1.9934933e+03   0.000000e+00   2.563883e+03     10s
#    19272    1.5915346e+03   0.000000e+00   2.229565e+03     15s
#    29571    7.3824800e+02   0.000000e+00   8.073196e+02     15s
#    24749    1.1670208e+03   0.000000e+00   1.268640e+03     15s
#    19721    1.5308536e+03   0.000000e+00   1.944721e+03     15s
#    22266    1.3493509e+03   0.000000e+00   1.583123e+03     15s
#    21441    1.4005899e+03   0.000000e+00   2.180507e+03     15s
#    19183    1.5850539e+03   0.000000e+00   2.741043e+03     15s
#    21294    1.5211286e+03   0.000000e+00   2.038593e+03     15s
#    32062    5.9797272e+02   0.000000e+00   7.768628e+02     20s
#    30081    7.7203225e+02   0.000000e+00   9.240082e+02     20s
#    24770    1.1282172e+03   0.000000e+00   1.016377e+03     20s
#    25612    1.0378680e+03   0.000000e+00   1.126726e+03     20s
#    30383    7.0309338e+02   0.000000e+00   1.165652e+03     20s
work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 737.334 4448.32
#
# Time limit reached
# Best objective 7.373337367417e+02, best bound 6.511094705092e+02, gap 11.6941%
#
# Explored 1798 nodes (99827 simplex iterations) in 400.40 seconds (86.73 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 667.641 4239.13
#
# Time limit reached
# Best objective 6.676413356246e+02, best bound 6.394438250361e+02, gap 4.2235%
#
# Explored 496 nodes (71428 simplex iterations) in 400.42 seconds (84.33 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 808.166 863.401 4767.27
#
# Time limit reached
# Warning: max constraint violation (3.8926e-06) exceeds tolerance
# Best objective 8.081658733634e+02, best bound 6.718731551383e+02, gap 16.8644%
#    398   116  707.30959   40   62  729.78414  603.61535  17.3%  91.7  400s
#
# Explored 187 nodes (59700 simplex iterations) in 400.32 seconds (77.65 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 730.048 4557.22
#
# Time limit reached
# Best objective 7.300477170817e+02, best bound 6.065855151851e+02, gap 16.9115%
# Set parameter TimeLimit to value 400
#   1438   490  689.97850  152   86  705.91445  595.63617  15.6%  48.5  400s
# Set parameter TimeLimit to value 400
#
# Explored 449 nodes (75579 simplex iterations) in 400.24 seconds (82.43 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 729.784 4304.97
#
# Time limit reached
# Best objective 7.297841350097e+02, best bound 6.036153490832e+02, gap 17.2885%
# Set parameter TimeLimit to value 400
# Set parameter TimeLimit to value 400
#    994   118  743.26507    7  119  788.10946  735.79244  6.64%  47.9  399s
#
# Explored 1504 nodes (108661 simplex iterations) in 400.14 seconds (84.32 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 705.914 739.823 4540.68
#
# Time limit reached
# Best objective 7.059144454120e+02, best bound 5.956361681840e+02, gap 15.6220%
# Set parameter TimeLimit to value 400
#   1052   117  746.10896  110   70  788.10946  735.79244  6.64%  47.2  400s
# Set parameter TimeLimit to value 400
#
# Explored 1055 nodes (85486 simplex iterations) in 400.07 seconds (82.30 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 788.109 4902.09
#
# Time limit reached
# Best objective 7.881094621553e+02, best bound 7.357924361712e+02, gap 6.6383%
# Set parameter TimeLimit to value 400
#
# Explored 1000 nodes (82635 simplex iterations) in 400.05 seconds (85.98 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 735.674 4537.19
#
# Time limit reached
# Warning: max constraint violation (6.5061e-06) exceeds tolerance
# Best objective 7.356738103235e+02, best bound 6.589516173328e+02, gap 10.4288%
# Set parameter TimeLimit to value 400
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xe7a76fb6
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [2e-04, 1e+02]
#   QObjective range [3e-09, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 5921.6433267
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xc89603f6
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e-04, 1e+02]
#   QObjective range [8e-08, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 6611.3970221
# Presolve time: 0.03s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0x83dcad32
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [2e-06, 1e+02]
#   QObjective range [4e-08, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 6470.0927967
# Variable types: 5000 continuous, 999 integer (999 binary)
# Presolve time: 0.02s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Presolve time: 0.03s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0x17a00ae3
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [6e-06, 1e+02]
#   QObjective range [1e-11, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Warning: Model contains large quadratic objective coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 6726.7660896
# Presolve time: 0.06s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0x200f6229
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-04, 1e+02]
#   QObjective range [5e-08, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 6607.9571656
# Presolve time: 0.10s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xd873eb73
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e-04, 1e+02]
#   QObjective range [1e-07, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 6731.4160430
# Presolve time: 0.12s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0xea60a28a
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e-05, 1e+02]
#   QObjective range [2e-09, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Warning: Model contains large quadratic objective coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 6818.2648706
# Presolve time: 0.13s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i9-10910 CPU @ 3.60GHz
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 10988 rows, 5999 columns and 33960 nonzeros
# Model fingerprint: 0x6acaaff2
# Model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e-05, 1e+02]
#   QObjective range [7e-10, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Warning: Model contains large quadratic objective coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 6635.1665891
# Presolve time: 0.12s
# Presolved: 10988 rows, 5999 columns, 33960 nonzeros
# Presolved model has 15000 quadratic objective terms
# Variable types: 5000 continuous, 999 integer (999 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11864    2.2734538e+03   0.000000e+00   2.840023e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11807    2.6267034e+03   0.000000e+00   3.420707e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    12416    2.4879029e+03   0.000000e+00   3.263546e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11933    2.4736270e+03   0.000000e+00   3.319234e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11985    2.4693481e+03   0.000000e+00   3.184151e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11916    2.5237774e+03   0.000000e+00   3.258465e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11888    2.5927839e+03   0.000000e+00   3.320780e+03      5s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11895    2.3732953e+03   0.000000e+00   3.311467e+03      5s
#    15752    1.8863951e+03   0.000000e+00   2.375244e+03     10s
#    16019    2.0468609e+03   0.000000e+00   2.434274e+03     10s
#    16466    2.0393537e+03   0.000000e+00   2.465348e+03     10s
#    16145    1.9161864e+03   0.000000e+00   2.262547e+03     10s
#    16035    1.8570610e+03   0.000000e+00   2.136174e+03     10s
#    16290    2.0429594e+03   0.000000e+00   2.359791e+03     10s
#    16100    2.0648228e+03   0.000000e+00   2.354981e+03     10s
#    16431    1.7949780e+03   0.000000e+00   2.255566e+03     10s
#    19154    1.6147676e+03   0.000000e+00   2.268246e+03     15s
#    19706    1.6706463e+03   0.000000e+00   1.766049e+03     15s
#    19259    1.6871549e+03   0.000000e+00   1.802989e+03     15s
#    19547    1.6541927e+03   0.000000e+00   1.779945e+03     15s
#    19437    1.5439832e+03   0.000000e+00   1.555706e+03     15s
#    19692    1.7533851e+03   0.000000e+00   1.937020e+03     15s
#    19502    1.7543361e+03   0.000000e+00   1.912389e+03     15s
#    19833    1.4644236e+03   0.000000e+00   1.598682e+03     15s
#    21851    1.5034209e+03   0.000000e+00   1.380734e+03     20s
#    22139    1.4112241e+03   0.000000e+00   1.302259e+03     20s
#    21908    1.3995312e+03   0.000000e+00   1.458722e+03     20s
#    22622    1.4215196e+03   0.000000e+00   1.254314e+03     20s
#    22750    1.2240006e+03   0.000000e+00   1.422972e+03     20s
#    22284    1.5347480e+03   0.000000e+00   1.476752e+03     20s
#    21932    1.5459952e+03   0.000000e+00   1.461427e+03     20s
#    22692    1.2482090e+03   0.000000e+00   1.588089e+03     20s
#    24267    1.3138481e+03   0.000000e+00   1.129662e+03     25s
#    25073    1.2290533e+03   0.000000e+00   1.068772e+03     25s
#    25820    1.0862926e+03   0.000000e+00   8.430872e+02     25s
#     25    36  821.09550    5  222 6611.39702  821.09550  87.6%   132   81s
#     15    26  788.45794    4  211 6470.09280  788.45794  87.8%   115   81s
#     25    36  849.85994    5  208 6731.41604  843.08683  87.5%  81.3   81s
#     25    36  814.45350    5  225 6726.76609  814.45350  87.9%   111   85s
#      7    16  858.04729    3  214 6818.26487  858.04729  87.4%   122   87s
#     25    36  790.61058    5  210 6470.09280  790.61058  87.8%   106   91s
#     15    26  859.38735    4  213 6818.26487  859.38735  87.4%   120   96s
#     25    36  860.28475    5  213 6818.26487  860.28475  87.4%   115  104s
#     35    46  810.31850    6  217 6607.95717  810.31850  87.7%  89.2  113s
# H   36    46                    1072.4641813  810.32882  24.4%  86.7  113s
#
# Explored 45 nodes (37201 simplex iterations) in 113.31 seconds (39.10 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 1072.46 6607.96
#
# Solve interrupted
# Best objective 1.072464181333e+03, best bound 8.103288206573e+02, gap 24.4423%
#     35    46  792.84216    6  210 6470.09280  792.84216  87.7%  96.3  113s
#     35    46  745.70548    6  227 6635.16659  745.70548  88.8%   104  111s
#     35    46  819.34008    6  194 5921.64333  819.34008  86.2%   106  113s
#     35    46  823.70095    6  222 6611.39702  823.67221  87.5%   110  113s
#     35    46  815.35969    6  225 6726.76609  815.35969  87.9%  98.1  113s
#     35    46  850.80921    6  210 6731.41604  843.08683  87.5%  71.5  113s
#
# Explored 45 nodes (38420 simplex iterations) in 111.43 seconds (36.24 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 6635.17
#
# Solve interrupted
# Best objective 6.635166589065e+03, best bound 7.457469234085e+02, gap 88.7607%
#
# Explored 45 nodes (39485 simplex iterations) in 113.74 seconds (38.19 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 5921.64
#
# Solve interrupted
# Best objective 5.921643326708e+03, best bound 8.193408686524e+02, gap 86.1636%
#
# Explored 45 nodes (39245 simplex iterations) in 113.16 seconds (38.43 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 6731.42
#
# Solve interrupted
# Best objective 6.731416043047e+03, best bound 8.430868291608e+02, gap 87.4753%
#
# Explored 45 nodes (39986 simplex iterations) in 113.72 seconds (38.36 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 6611.4
#
# Solve interrupted
# Best objective 6.611397022101e+03, best bound 8.236722052390e+02, gap 87.5416%
# Set parameter TimeLimit to value 400
#
# Explored 45 nodes (40291 simplex iterations) in 113.71 seconds (37.34 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 6470.09
#
# Solve interrupted
# Best objective 6.470092796738e+03, best bound 7.929929271079e+02, gap 87.7437%
# Set parameter TimeLimit to value 400
# Set parameter TimeLimit to value 400
# Set parameter TimeLimit to value 400
# Set parameter TimeLimit to value 400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 73>()
#      70                 writer.writerow(resultrow)
#      71                 f.close()
# ---> 73 Parallel(n_jobs = 8)(delayed(to_repeat)(rep) for rep in range(500))
#
# File /opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File /opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File /opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File /opt/anaconda3/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     436 elif self._state == FINISHED:
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     442     raise CancelledError()
#
# File /opt/anaconda3/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
bigM
# Out:
# 8.833158764852824
